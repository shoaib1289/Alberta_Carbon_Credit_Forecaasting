# %%
pip install duckdb
# Out:
# Requirement already satisfied: duckdb in c:\users\shoaib\anaconda3\lib\site-packages (1.4.4)Note: you may need to restart the kernel to use updated packages.

# %%
import duckdb
con = duckdb.connect("carbon_offsets.duckdb")
con.execute("""
DROP TABLE IF EXISTS offsets_stage_v2;
DROP TABLE IF EXISTS offsets_clean_v2;
""")

# %%
con.execute("""
CREATE TEMP TABLE raw_offsets_v2 AS
SELECT *
FROM read_csv_auto(
  'combined_data.csv',
  HEADER = TRUE,
  SAMPLE_SIZE = 100000
);
""")
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))

# %%
con.execute("""DESCRIBE raw_offsets_v2;
""").df()
# Out:
#                           column_name column_type null   key default extra
# 0                            Registry     VARCHAR  YES  None    None  None
# 1                  Project_Identifier     VARCHAR  YES  None    None  None
# 2                       Project_Title     VARCHAR  YES  None    None  None
# 3   Emission_Offset_Project_Developer     VARCHAR  YES  None    None  None
# 4             Quantification_Protocol     VARCHAR  YES  None    None  None
# 5                             Vintage      BIGINT  YES  None    None  None
# 6                        Serial_Start     VARCHAR  YES  None    None  None
# 7                          Serial_End     VARCHAR  YES  None    None  None
# 8                                Type     VARCHAR  YES  None    None  None
# 9                            Quantity      BIGINT  YES  None    None  None
# 10                      Current_Owner     VARCHAR  YES  None    None  None
# 11                           Facility     VARCHAR  YES  None    None  None
# 12             Emission_Offset_Status     VARCHAR  YES  None    None  None
# 13                     Transaction_Id      DOUBLE  YES  None    None  None
# 14                     Activity_Start        DATE  YES  None    None  None
# 15                  Offset_Start_Date        DATE  YES  None    None  None
# 16                    Offset_End_Date        DATE  YES  None    None  None
# 17                        Expiry_Date        DATE  YES  None    None  None
# 18                   Verifier_Company     VARCHAR  YES  None    None  None
# 19                    Compliance_Year      BIGINT  YES  None    None  None
# 20                     Effective_Date        DATE  YES  None    None  None

# %%
con.execute("""SELECT COUNT(*) AS raw_row_count FROM raw_offsets_v2;
""").df()
# Out:
#    raw_row_count
# 0        1048575

# %%
con.execute("""SELECT * FROM raw_offsets_v2 LIMIT 5;
""").df()
# Out:
#   Registry Project_Identifier                 Project_Title  \
# 0     AEOR          8626-3432  2007 Tillage Auction Project
# 1     AEOR          8626-3432  2007 Tillage Auction Project
# 2     AEOR          8626-3432  2007 Tillage Auction Project
# 3     AEOR          8626-3432  2007 Tillage Auction Project
# 4     AEOR          8626-3432  2007 Tillage Auction Project
#
#     Emission_Offset_Project_Developer     Quantification_Protocol  Vintage  \
# 0  Emission Credits Corporation (ECC)  Tillage System Management      2007
# 1  Emission Credits Corporation (ECC)  Tillage System Management      2006
# 2  Emission Credits Corporation (ECC)  Tillage System Management      2005
# 3  Emission Credits Corporation (ECC)  Tillage System Management      2004
# 4  Emission Credits Corporation (ECC)  Tillage System Management      2003
#
#                 Serial_Start                 Serial_End  Type  Quantity  ...  \
# 0  8626-3432-000-000-070-058  8626-3432-000-000-107-037  None     36980  ...
# 1  8626-3432-000-000-055-706  8626-3432-000-000-070-057  None     14352  ...
# 2  8626-3432-000-000-041-500  8626-3432-000-000-055-705  None     14206  ...
# 3  8626-3432-000-000-013-653  8626-3432-000-000-027-541  None     13889  ...
# 4  8626-3432-000-000-027-542  8626-3432-000-000-041-499  None     13958  ...
#
#   Facility Emission_Offset_Status Transaction_Id  Activity_Start  \
# 0     None                Revoked            NaN             NaT
# 1     None                Revoked            NaN             NaT
# 2     None                Revoked            NaN             NaT
# 3     None                Revoked            NaN             NaT
# 4     None                Revoked            NaN             NaT
#
#   Offset_Start_Date Offset_End_Date Expiry_Date Verifier_Company  \
# 0        2002-01-01      2007-12-31  2021-07-05             None
# 1        2002-01-01      2007-12-31  2021-07-05             None
# 2        2002-01-01      2007-12-31  2021-07-05             None
# 3        2002-01-01      2007-12-31  2021-07-05             None
# 4        2002-01-01      2007-12-31  2021-07-05             None
#
#   Compliance_Year  Effective_Date
# 0            <NA>      2024-01-01
# 1            <NA>      2024-01-01
# 2            <NA>      2024-01-01
# 3            <NA>      2024-01-01
# 4            <NA>      2024-01-01
#
# [5 rows x 21 columns]

# %%
con.execute("""SELECT Registry, COUNT(*) AS n
FROM raw_offsets_v2
GROUP BY 1
ORDER BY n DESC
LIMIT 10;
""").df()
# Out:
#   Registry        n
# 0     AEOR  1048575

# %%
con.execute("""CREATE TABLE offsets_stage_v2 AS
SELECT
  UPPER(TRIM(CAST(Registry AS VARCHAR))) AS registry,
  TRIM(CAST(Project_Identifier AS VARCHAR)) AS project_id,
  TRIM(CAST(Project_Title AS VARCHAR)) AS project_title,
  TRIM(CAST(Emission_Offset_Project_Developer AS VARCHAR)) AS developer,

  REPLACE(REPLACE(TRIM(CAST(Quantification_Protocol AS VARCHAR)), 'Â', ''), '�', '') AS quantification_protocol,

  NULLIF(TRIM(CAST(Type AS VARCHAR)), '') AS project_type,
  TRY_CAST(NULLIF(TRIM(CAST(Vintage AS VARCHAR)), '') AS INTEGER) AS vintage,
  TRY_CAST(NULLIF(TRIM(CAST(Quantity AS VARCHAR)), '') AS BIGINT) AS quantity,

  NULLIF(TRIM(CAST(Current_Owner AS VARCHAR)), '') AS current_owner,
  NULLIF(TRIM(CAST(Facility AS VARCHAR)), '') AS facility,

  NULLIF(TRIM(CAST(Emission_Offset_Status AS VARCHAR)), '') AS offset_status,
  NULLIF(TRIM(CAST(Transaction_Id AS VARCHAR)), '') AS transaction_id,

  -- Keep serials as strings
  NULLIF(TRIM(CAST(Serial_Start AS VARCHAR)), '') AS serial_start,
  NULLIF(TRIM(CAST(Serial_End AS VARCHAR)), '') AS serial_end,

  NULLIF(TRIM(CAST(Verifier_Company AS VARCHAR)), '') AS verifier_company,
  TRY_CAST(NULLIF(TRIM(CAST(Compliance_Year AS VARCHAR)), '') AS INTEGER) AS compliance_year,

  -- Raw date strings (parse next step)
  NULLIF(TRIM(CAST(Activity_Start AS VARCHAR)), '') AS activity_start_raw,
  NULLIF(TRIM(CAST(Offset_Start_Date AS VARCHAR)), '') AS offset_start_raw,
  NULLIF(TRIM(CAST(Offset_End_Date AS VARCHAR)), '') AS offset_end_raw,
  NULLIF(TRIM(CAST(Expiry_Date AS VARCHAR)), '') AS expiry_raw,
  NULLIF(TRIM(CAST(Effective_Date AS VARCHAR)), '') AS effective_raw
FROM raw_offsets_v2;
""")
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))

# %%
con.execute("""SELECT COUNT(*) AS stage_row_count FROM offsets_stage_v2;
""").df()
# Out:
#    stage_row_count
# 0          1048575

# %%
con.execute("""
SELECT
  SUM(CASE WHEN quantity IS NULL THEN 1 ELSE 0 END) AS missing_quantity,
  SUM(CASE WHEN quantity <= 0 THEN 1 ELSE 0 END) AS non_positive_quantity,
  MIN(quantity) AS min_quantity,
  MAX(quantity) AS max_quantity
FROM offsets_stage_v2;
""").df()
# Out:
#    missing_quantity  non_positive_quantity  min_quantity  max_quantity
# 0               0.0                20751.0             0        768138

# %%
con.execute("""
SELECT
  SUM(CASE WHEN project_type IS NULL THEN 1 ELSE 0 END) AS missing_type,
  SUM(CASE WHEN facility IS NULL THEN 1 ELSE 0 END) AS missing_facility,
  SUM(CASE WHEN transaction_id IS NULL THEN 1 ELSE 0 END) AS missing_transaction_id,
  SUM(CASE WHEN activity_start_raw IS NULL THEN 1 ELSE 0 END) AS missing_activity_start
FROM offsets_stage_v2;
""").df()
# Out:
#    missing_type  missing_facility  missing_transaction_id  \
# 0     1045359.0         1022894.0                739632.0
#
#    missing_activity_start
# 0                864695.0

# %%
con.execute("""
SELECT registry, COUNT(*) AS n
FROM offsets_stage_v2
GROUP BY 1
ORDER BY n DESC
LIMIT 10;
""").df()
# Out:
#   registry        n
# 0     AEOR  1048575

# %%
con.execute("""
CREATE TABLE offsets_clean_v2 AS
SELECT
  *,
  -- activity_start_dt: mostly missing, parse if available
  CASE
    WHEN activity_start_raw IS NULL THEN NULL
    WHEN REGEXP_MATCHES(activity_start_raw, '^\d{4}-\d{2}-\d{2}$') THEN TRY_CAST(activity_start_raw AS DATE)
    WHEN REGEXP_MATCHES(activity_start_raw, '^\d{1,2}/\d{1,2}/\d{4}$') THEN STRPTIME(activity_start_raw, '%m/%d/%Y')::DATE
    ELSE NULL
  END AS activity_start_dt,

  CASE
    WHEN offset_start_raw IS NULL THEN NULL
    WHEN REGEXP_MATCHES(offset_start_raw, '^\d{4}-\d{2}-\d{2}$') THEN TRY_CAST(offset_start_raw AS DATE)
    WHEN REGEXP_MATCHES(offset_start_raw, '^\d{1,2}/\d{1,2}/\d{4}$') THEN STRPTIME(offset_start_raw, '%m/%d/%Y')::DATE
    ELSE NULL
  END AS offset_start_dt,

  CASE
    WHEN offset_end_raw IS NULL THEN NULL
    WHEN REGEXP_MATCHES(offset_end_raw, '^\d{4}-\d{2}-\d{2}$') THEN TRY_CAST(offset_end_raw AS DATE)
    WHEN REGEXP_MATCHES(offset_end_raw, '^\d{1,2}/\d{1,2}/\d{4}$') THEN STRPTIME(offset_end_raw, '%m/%d/%Y')::DATE
    ELSE NULL
  END AS offset_end_dt,

  CASE
    WHEN expiry_raw IS NULL THEN NULL
    WHEN REGEXP_MATCHES(expiry_raw, '^\d{4}-\d{2}-\d{2}$') THEN TRY_CAST(expiry_raw AS DATE)
    WHEN REGEXP_MATCHES(expiry_raw, '^\d{1,2}/\d{1,2}/\d{4}$') THEN STRPTIME(expiry_raw, '%m/%d/%Y')::DATE
    ELSE NULL
  END AS expiry_dt,

  CASE
    WHEN effective_raw IS NULL THEN NULL
    WHEN REGEXP_MATCHES(effective_raw, '^\d{4}-\d{2}-\d{2}$') THEN TRY_CAST(effective_raw AS DATE)
    WHEN REGEXP_MATCHES(effective_raw, '^\d{1,2}/\d{1,2}/\d{4}$') THEN STRPTIME(effective_raw, '%m/%d/%Y')::DATE
    ELSE NULL
  END AS effective_dt
FROM offsets_stage_v2;
""")
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))

# %%
con.execute("""
SELECT COUNT(*) AS clean_row_count FROM offsets_clean_v2;
""").df()
# Out:
#    clean_row_count
# 0          1048575

# %%
con.execute("""
SELECT * FROM offsets_clean_v2 LIMIT 5;
""").df()
# Out:
#   registry project_id                 project_title  \
# 0     AEOR  8626-3432  2007 Tillage Auction Project
# 1     AEOR  8626-3432  2007 Tillage Auction Project
# 2     AEOR  8626-3432  2007 Tillage Auction Project
# 3     AEOR  8626-3432  2007 Tillage Auction Project
# 4     AEOR  8626-3432  2007 Tillage Auction Project
#
#                             developer    quantification_protocol project_type  \
# 0  Emission Credits Corporation (ECC)  Tillage System Management         None
# 1  Emission Credits Corporation (ECC)  Tillage System Management         None
# 2  Emission Credits Corporation (ECC)  Tillage System Management         None
# 3  Emission Credits Corporation (ECC)  Tillage System Management         None
# 4  Emission Credits Corporation (ECC)  Tillage System Management         None
#
#    vintage  quantity              current_owner facility  ...  \
# 0     2007     36980  Heartland Generation Ltd.     None  ...
# 1     2006     14352  Heartland Generation Ltd.     None  ...
# 2     2005     14206  Heartland Generation Ltd.     None  ...
# 3     2004     13889  Heartland Generation Ltd.     None  ...
# 4     2003     13958  Heartland Generation Ltd.     None  ...
#
#   activity_start_raw offset_start_raw offset_end_raw  expiry_raw  \
# 0               None       2002-01-01     2007-12-31  2021-07-05
# 1               None       2002-01-01     2007-12-31  2021-07-05
# 2               None       2002-01-01     2007-12-31  2021-07-05
# 3               None       2002-01-01     2007-12-31  2021-07-05
# 4               None       2002-01-01     2007-12-31  2021-07-05
#
#   effective_raw  activity_start_dt offset_start_dt offset_end_dt  expiry_dt  \
# 0    2024-01-01                NaT      2002-01-01    2007-12-31 2021-07-05
# 1    2024-01-01                NaT      2002-01-01    2007-12-31 2021-07-05
# 2    2024-01-01                NaT      2002-01-01    2007-12-31 2021-07-05
# 3    2024-01-01                NaT      2002-01-01    2007-12-31 2021-07-05
# 4    2024-01-01                NaT      2002-01-01    2007-12-31 2021-07-05
#
#   effective_dt
# 0   2024-01-01
# 1   2024-01-01
# 2   2024-01-01
# 3   2024-01-01
# 4   2024-01-01
#
# [5 rows x 26 columns]

# %%
con.execute("""
SELECT
  MIN(offset_start_dt) AS min_offset_start,
  MAX(offset_start_dt) AS max_offset_start,
  MIN(offset_end_dt) AS min_offset_end,
  MAX(offset_end_dt) AS max_offset_end,
  MIN(expiry_dt) AS min_expiry,
  MAX(expiry_dt) AS max_expiry
FROM offsets_clean_v2;
""").df()
# Out:
#   min_offset_start max_offset_start min_offset_end max_offset_end min_expiry  \
# 0       2002-01-01       2024-05-28     2003-12-31     2039-02-25 2019-07-05
#
#   max_expiry
# 0 2033-07-05

# %%
con.execute("""
SELECT COUNT(*) AS invalid_offset_date_range
FROM offsets_clean_v2
WHERE offset_start_dt IS NOT NULL
  AND offset_end_dt IS NOT NULL
  AND offset_start_dt > offset_end_dt;
""").df()
# Out:
#    invalid_offset_date_range
# 0                          0

# %%
con.execute("""
ALTER TABLE offsets_clean_v2 ADD COLUMN data_quality_flag VARCHAR;

-- Standardize status
UPDATE offsets_clean_v2
SET offset_status = UPPER(TRIM(offset_status))
WHERE offset_status IS NOT NULL;

UPDATE offsets_clean_v2
SET data_quality_flag =
  CASE
    WHEN quantity IS NULL OR quantity <= 0 THEN 'INVALID_QUANTITY'
    WHEN offset_start_dt IS NULL OR offset_end_dt IS NULL THEN 'MISSING_OFFSET_DATES'
    WHEN offset_start_dt > offset_end_dt THEN 'INVALID_DATE_RANGE'
    WHEN expiry_dt IS NOT NULL AND offset_end_dt IS NOT NULL AND expiry_dt < offset_end_dt THEN 'EXPIRY_BEFORE_END'
    WHEN vintage IS NOT NULL AND (vintage < 1990 OR vintage > 2050) THEN 'SUSPICIOUS_VINTAGE'
    ELSE 'VALID'
  END;
""")

# %%
con.execute("""
SELECT data_quality_flag, COUNT(*) AS n
FROM offsets_clean_v2
GROUP BY 1
ORDER BY n DESC;
""").df()
# Out:
#    data_quality_flag       n
# 0              VALID  854358
# 1  EXPIRY_BEFORE_END  173466
# 2   INVALID_QUANTITY   20751

# %%
con.execute("""
SELECT project_id, quantity, offset_start_dt, offset_end_dt, expiry_dt, data_quality_flag
FROM offsets_clean_v2
WHERE data_quality_flag <> 'VALID'
LIMIT 20;
""").df()
# Out:
#    project_id  quantity offset_start_dt offset_end_dt  expiry_dt  \
# 0   3434-3994      2582      2015-12-21    2023-12-20 2022-07-05
# 1   3434-3994      3761      2015-12-21    2023-12-20 2022-07-05
# 2   2691-7190         0      2016-01-01    2023-12-31        NaT
# 3   9273-8648     18159      2021-06-02    2031-06-01 2030-07-05
# 4   9273-8648       946      2021-06-02    2031-06-01 2030-07-05
# 5   9273-8648         7      2021-06-02    2031-06-01 2030-07-05
# 6   9273-8648      9842      2021-06-02    2031-06-01 2030-07-05
# 7   9273-8648        40      2021-06-02    2031-06-01 2030-07-05
# 8   9623-5362     13473      2022-05-31    2032-05-30 2031-07-05
# 9   7749-0748         0      2022-08-18    2032-08-17        NaT
# 10  6903-6862         0      2023-04-11    2033-04-10        NaT
# 11  9574-8716         0      2023-10-16    2033-10-15        NaT
# 12  7397-3419         0      2015-01-01    2022-12-31        NaT
# 13  7645-4105         0      2021-04-05    2029-04-04        NaT
# 14  3407-2966         0      2023-04-01    2033-03-31        NaT
# 15  0773-2296         0      2022-12-07    2030-12-07        NaT
# 16  2366-9941         0      2022-01-31    2030-01-30        NaT
# 17  1645-6019         0      2022-12-10    2030-12-09        NaT
# 18  9655-7197         0      2023-03-17    2033-03-16        NaT
# 19  3170-4598      1634      2013-01-01    2025-12-31 2022-07-05
#
#     data_quality_flag
# 0   EXPIRY_BEFORE_END
# 1   EXPIRY_BEFORE_END
# 2    INVALID_QUANTITY
# 3   EXPIRY_BEFORE_END
# 4   EXPIRY_BEFORE_END
# 5   EXPIRY_BEFORE_END
# 6   EXPIRY_BEFORE_END
# 7   EXPIRY_BEFORE_END
# 8   EXPIRY_BEFORE_END
# 9    INVALID_QUANTITY
# 10   INVALID_QUANTITY
# 11   INVALID_QUANTITY
# 12   INVALID_QUANTITY
# 13   INVALID_QUANTITY
# 14   INVALID_QUANTITY
# 15   INVALID_QUANTITY
# 16   INVALID_QUANTITY
# 17   INVALID_QUANTITY
# 18   INVALID_QUANTITY
# 19  EXPIRY_BEFORE_END

# %%
df_clean = con.execute("SELECT * FROM offsets_clean_v2").df()
df_clean.to_csv("offsets_clean.csv", index=False)
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\shoaib
